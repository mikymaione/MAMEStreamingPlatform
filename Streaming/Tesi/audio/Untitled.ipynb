# %%
import librosa
import scipy
import numpy as np
import matplotlib.pyplot as plt

from librosa import display

# %%
file_path = "sf3.wav"
samples, sampling_rate = librosa.load(file_path, mono = True)

len(samples), sampling_rate
# Out:
# (221399, 22050)

# %%
duration_of_sound = len(samples) / sampling_rate
print(duration_of_sound, "s")
# Out:
# 10.04077097505669 s

# %%
plt.figure(figsize=(5,5))
librosa.display.waveplot(y = samples, sr = sampling_rate)
plt.xlabel("Tempo")
plt.ylabel("Ampiezza")
plt.grid()
plt.show()

# %%
n = len(samples)
T = 1 / sampling_rate
yf = scipy.fft(samples)
xf = np.linspace(0.0, 1.0 / (2.0 * T), n // 2)
# Out:
# <ipython-input-5-e7897f7bcf2a>:3: DeprecationWarning: Using scipy.fft as a function is deprecated and will be removed in SciPy 1.5.0, use scipy.fft.fft instead.
#   yf = scipy.fft(samples)

# %%
plt.figure(figsize=(5,5))
plt.plot(xf, 2.0 / n * np.abs(yf[:n//2]))
plt.xlabel("Frequenza")
plt.ylabel("Magnitudine")
plt.grid()
plt.show()
